# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

import numdifftools as nd
from scipy import optimize
from scipy.optimize import fsolve
import numpy as np
from numpy import *
from scipy.optimize import fsolve
from ions import Chain
from ion_trap import IonTrap
import scipy.linalg as LA
import matplotlib.pylab as plt
import pickle
import pandas as pd
from simulation_parameters import *
p = SimulationParameters()
from quantum_dynamics import *
import seaborn as sns
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
def get_ramsey_contrast(chain, ion_num, times, creation_op_num = 0, time_precision=1.e-6):
        """Return an array of amplitudes of ion ion_num at each time in time_interval   

        """
        eigen = LA.eig(chain.get_couplings())
        eigenvectorsT = eigen[1]
        eigenfreqs   = eigen[0]

        def gamma(l, j, t, chain):
            
            s = 0
            for k in range(chain.num_of_ions):
                s += eigenvectorsT[:,k][l] * eigenvectorsT[:,k][j] * np.exp(1.j* eigenfreqs[k] * t)
            return s
        
        #time_interval = [0., 700.e-6]
        #times = np.arange(0., 700.e-6, time_precision)

        
        l = ion_num
        j = creation_op_num
        ex = abs(np.conjugate(np.array([gamma(l, j, t, chain) for t in times])) * np.array([gamma(l, j, t, chain) for t in times]))
        return ex, np.array([gamma(l, j, t, chain) for t in times])

# %%
pkl_vis8 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/visibility_8ions.p", "r" ) ) 
pkl_err8 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/verr_8ions.p", "r" ) ) 
#f=pd.read_csv("/home/trxw/Documents/dfr/Experiments/Lattice/Fines/8ions/8ions_DephaseScanDurationPhase2015Apr10_1314_49_contrast.csv")
#pkl_contrast8 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/old_contrast/contrast_8ions.p", "r" ) ) 

#pkl_contrast14 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/Fines/14ions/contrast_14ions.p", "r" ) ) 
pkl_vis25 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/visibility_25ions.p", "r" ) ) 
pkl_err25 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/verr_25ions.p", "r" ) ) 

#csv_contrast25 = pd.read_csv( open( "/home/trxw/Documents/dfr/Experiments/Lattice/Fines/25ions/cleaned_25ions_all_phases.csv", "r" )   )
#pkl_vis41 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/data/visibility_41ions.p", "r" ) )
pkl_vis41 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/visibility_41ions.p", "r" ) )
pkl_err41 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/verr_41ions.p", "r" ) )

pkl_vis33 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/visibility_33ions.p", "r" ) )
pkl_err33 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/verr_33ions.p", "r" ) )

#pkl_contrast41_prev = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/Fines/41ions/contrast_41ions.p", "r" ) )
#pkl_error41_prev = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/Fines/41ions/errorbars_41ions.p", "r" ) )
#pkl_error41_prev = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/prev/errorbars_41ions.p", "r" ) )
#f=pd.read_csv("/home/trxw/Documents/dfr/Experiments/Lattice/Fines/14Ions_NoExtra729_DephaseScanDurationPhase2015Jan14_1744_36_contrast.csv")
#f41=pd.read_csv("/home/trxw/Documents/dfr/Experiments/Lattice/Fines/2015Jan06_41Ions/cleaned_41ions_contrast.csv")
#rabi41 = pd.read_csv("/home/trxw/Documents/dfr/Experiments/Lattice/Fines/2015Jan06_41Ions/41Ions_RabiFlopping2015Jan06_1752_22.csv")
pkl_vis42 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/visibility_42ions.p", "r" ) )
pkl_err42 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/verr_42ions.p", "r" ) )
pkl_vis14 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/visibility_14ions.p", "r" ) )
pkl_err14 = pickle.load( open( "/home/trxw/Documents/dfr/Experiments/Lattice/AnalyzedData/AllFinalAnalyzed/verr_14ions.p", "r" ) )

# %%
N=8
omegax = 2.057e6
omegaz = 195.8e3#136.7e3
ratio = .67
pkl = pkl_vis8
pkl_err = pkl_err8




N=14
omegax = 2.057e6
omegaz = 152.7e3#136.7e3
pkl = pkl_vis14
pkl_err = pkl_err14
ratio = .80


N = 25
omegax = 2.1178e6
omegaz = 98.e3
pkl = pkl_vis25
pkl_err = pkl_err25
ratio = .66


N = 33
omegax = 2.057e6
omegaz = 117.1e3
pkl = pkl_vis33[:178]
pkl_err = pkl_err33[:178]
ratio = .72

N = 41
omegax = 2.057e6
omegaz = 77.3e3
pkl = pkl_vis41
pkl_err = pkl_err41
ratio = .82


N=42
omegax = 2.057e6
omegaz = 110.1e3#136.7e3
pkl = pkl_vis42
pkl_err = pkl_err42
ratio = .67

chain = Chain(N)
trap_potential = poly1d([0.5*p.mass*(2*pi*omegaz)**2/p.charge,0,0])
dummy_trap     = IonTrap() 
dummy_trap.set_trap_radial_freq(omegax, 'X')
dummy_trap.set_trap_radial_freq(omegax, 'Y')
dummy_trap.potential.set_fz(trap_potential)
dummy_trap.load(chain)
position_arr  =   np.array( chain.get_positions() ) 

###################################################################

time = np.array([pkl[i][0] for i in range(len(pkl))])*1.e-6
timeSim = linspace(time[0], time[-1], 600)
#error = [[pkl[i][1]-pkl_err[i][0] for i in range(len(pkl_err))], [pkl_err[i][1]-pkl[i][1] for i in range(len(pkl_err))]]
error = [[pkl[i][1]-pkl_err[i][1][0] for i in range(len(pkl_err))], [pkl_err[i][1][1]-pkl[i][1] for i in range(len(pkl_err))]]

x = time
y = [pkl[i][1] for i in range(len(pkl))]
#plt.errorbar(x/(1.e-6), y, yerr=error, fmt='--o', ecolor='r', linewidth=1)
plt.errorbar(x/(1.e-6), y, yerr=error,fmt=".k", ecolor='r', capthick=.7,  linewidth=.45)

q = .65
gamma = np.sqrt(np.array(get_ramsey_contrast(chain, 0, timeSim)[0]))
#gamma = imag(get_ramsey_contrast(chain, 0, time)[1])**2
visibility = 2.*gamma/( 3-gamma**2 )
visibilityposition = np.sqrt( (np.sqrt(0.5)*gamma + np.sqrt( 1- (np.sqrt(0.5)*gamma)**2))**2 -1 )
visibilityp = 2*q*gamma/( q*(1+gamma**2) + 1-gamma**2 )

#plt.plot(timeSim/(1.e-6), visibilityp, 'y')
plt.plot(timeSim/(1.e-6), ratio*gamma, 'b', linewidth=.9)#, label="ratio={:.2f}".format(ratio))#, 'g', label="Energy")
#plt.title("42 ions")
#plt.plot(timeSim/(1.e-6), ratio2*gamma, 'y', label="ratio={:.2f}".format(ratio2))
#plt.plot(timeSim/(1.e-6), ratio3*gamma, 'b', label="ratio={:.2f}".format(ratio3))
#plt.ylim([0,1])

#plt.plot(old_time/(1.e-6), gamma, 'b')
#plt.plot(time/(1.e-6), visibilityp, 'r', label="Thermal state")

plt.xlabel('Time [$\mu s$]', fontsize=14)
# plt.legend()
# plt.xlim([time[0]/1.e-6,time[-1]/1.e-6])
plt.ylabel("Visbility", fontsize=14)
plt.savefig('../../../../LatticePaper/42ions.pdf')
plt.show()
# Out:
# ('positions ', array([ -1.23222608e-04,  -1.12280971e-04,  -1.03426898e-04,
#         -9.56364201e-05,  -8.85204307e-05,  -8.18792520e-05,
#         -7.55934365e-05,  -6.95843581e-05,  -6.37967078e-05,
#         -5.81896042e-05,  -5.27316318e-05,  -4.73978662e-05,
#         -4.21679886e-05,  -3.70250336e-05,  -3.19545252e-05,
#         -2.69438602e-05,  -2.19818526e-05,  -1.70583873e-05,
#         -1.21641488e-05,  -7.29039915e-06,  -2.42879212e-06,
#          2.42879212e-06,   7.29039915e-06,   1.21641488e-05,
#          1.70583873e-05,   2.19818526e-05,   2.69438602e-05,
#          3.19545252e-05,   3.70250336e-05,   4.21679886e-05,
#          4.73978662e-05,   5.27316318e-05,   5.81896042e-05,
#          6.37967078e-05,   6.95843581e-05,   7.55934365e-05,
#          8.18792520e-05,   8.85204307e-05,   9.56364201e-05,
#          1.03426898e-04,   1.12280971e-04,   1.23222608e-04]))

# %%
#x8 = time
#y8 = y
#xsim8 = timeSim
#ysim8 = ratio*gamma
#error8 = error

# x14 = time
# y14 = y
# xsim14 = timeSim
# ysim14 = ratio*gamma
# error14 = error

# x25 = time
# y25 = y
# xsim25 = timeSim
# ysim25 = ratio*gamma
# error25 = error

# x33 = time
# y33 = y
# xsim33 = timeSim
# ysim33 = ratio*gamma
# error33 = error

# x41 = time
# y41 = y
# xsim41 = timeSim
# ysim41 = ratio*gamma
# error41 = error


x42 = time
y42 = y
xsim42 = timeSim
ysim42 = ratio*gamma
error42 = error

# %%
import numpy
a = numpy.asarray([ [1,2,3], [4,5,6], [7,8,9] ])
numpy.savetxt("../../../foo.csv", a, delimiter=",")

# %%
#Saving resutls as csv file
import pandas
yourlist = [x8, y8]#, error8[0], error8[1], xsim8, ysim8]
columns = ["time(microsec)","visibility"]#,"error-low", "error-high" ,"time(microS)","simulation"] #a csv with 3 columns
index = [i[0] for i in yourlist] #first element of every list in yourlist

pd = pandas.DataFrame(yourlist, columns = columns)#, index = index)

#Now you have a csv with columns and index:
pd.to_csv("../../../../LatticePaper/8ions.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-83-b141bed3415f> in <module>()
#       5 index = [i[0] for i in yourlist] #first element of every list in yourlist
#       6
# ----> 7 pd = pandas.DataFrame(yourlist, columns = columns)#, index = index)
#       8
#       9 #Now you have a csv with columns and index:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     243             if len(data) > 0:
#     244                 if is_list_like(data[0]) and getattr(data[0], 'ndim', 1) == 1:
# --> 245                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     246                     columns = _ensure_index(columns)
#     247
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _to_arrays(data, columns, coerce_float, dtype)
#    4760         return _list_to_arrays(data, columns,
#    4761                                coerce_float=coerce_float,
# -> 4762                                dtype=dtype)
#    4763
#    4764
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _list_to_arrays(data, columns, coerce_float, dtype)
#    4819         content = list(lib.to_object_array(data).T)
#    4820     return _convert_object_array(content, columns, dtype=dtype,
# -> 4821                                  coerce_float=coerce_float)
#    4822
#    4823
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _convert_object_array(content, columns, coerce_float, dtype)
#    4877             # caller's responsibility to check for this...
#    4878             raise AssertionError('%d columns passed, passed data had %s '
# -> 4879                                  'columns' % (len(columns), len(content)))
#    4880
#    4881     # provide soft conversion of object dtypes
#
# AssertionError: 2 columns passed, passed data had 221 columns

# %%
from numpy import *
from pylab import *
import matplotlib as mpl

rc('font',**{'family':'sans-serif','sans-serif':['Arial']})
#mpl.rcParams['font.sans-serif']='Arial'
mpl.rcParams.update({'font.size': 8})

inch = 1/2.54
figure(figsize=(8*inch,6*inch))
figure(figsize=(12*inch,6*inch)) #Two column figure

x = arange(20)/10. * pi
plot(x,sin(x))
plot(x,cos(x))

xlabel('xlabel')
ylabel('ylabel')
gcf().subplots_adjust(bottom=0.15, left=0.2)
show()
savefig('testfig.pdf')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
"""Examples illustrating the use of plt.subplots().

This function creates a figure and a grid of subplots with a single call, while
providing reasonable control over how the individual plots are created.  For
very refined tuning of subplot creation, you can still use add_subplot()
directly on a new figure.
"""

import matplotlib.pyplot as plt
import numpy as np
# Simple data to display in various forms
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)



# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
#f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
plt.xlim(0,100)
# row and column sharing
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
ax1.plot(x, y)

#ax1.xaxis.label ="time"

#ax1.set_title('Sharing x per column, y per row')
ax2.plot(x, y)
ax3.plot(x, 2 * y ** 2 - 1, color='r')
ax4.plot(x, 2 * y ** 2 - 1, color='r')

# Fine-tune figure; hide x ticks for top plots and y ticks for right plots
plt.setp([a.get_xticklabels() for a in axarr[0, :]], visible=False)
plt.setp([a.get_yticklabels() for a in axarr[:, 1]], visible=False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-10c79c509df2> in <module>()
#      18 # all but bottom plot.
#      19 #f.subplots_adjust(hspace=0)
# ---> 20 plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
#      21 plt.xlim(0,100)
#      22 # row and column sharing
#
# NameError: name 'f' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(2,2)


ax[0,0].errorbar(x14/(1.e-6), y14, yerr=error14, fmt=".k", ecolor='r', capthick=.7,  linewidth=.45)
ax[0,0].plot(xsim14/(1.e-6), ysim14, 'b', linewidth=.9 )
#ax[0,0].set_title("14 ions")
ax[0,0].set_ylabel("Visibility", fontsize=14)
ax[0,0].set_ylim(0,1)
ax[0,1].errorbar(x25/(1.e-6), y25, yerr=error25, fmt=".k", ecolor='r', capthick=.7,  linewidth=.45)
ax[0,1].plot(xsim25/(1.e-6), ysim25, 'b', linewidth=.9)
#ax[0,1].set_title("25 ions")
ax[0,1].set_ylim(0,1)

ax[1,0].errorbar(x33/(1.e-6), y33, yerr=error33, fmt=".k", ecolor='r', capthick=.7,  linewidth=.45)
ax[1,0].plot(xsim33/(1.e-6), ysim33, 'b', linewidth=.9)
#ax[1,0].set_title("33 ions")
ax[1,0].set_xlabel('Time [$\mu s$]', fontsize=14)
ax[1,0].set_ylabel("Visibility", fontsize=14)
ax[1,0].set_ylim(0,1)

ax[1,1].errorbar(x41/(1.e-6), y41, yerr=error41, fmt=".k", ecolor='r', capthick=.7,  linewidth=.45)
ax[1,1].plot(xsim41/(1.e-6), ysim41, 'b', linewidth=.9)
#ax[1,1].set_title("41 ions")
ax[1,1].set_xlabel('Time [$\mu s$]', fontsize=14)
ax[1,1].set_ylim(0,1)

#fig.legend(loc='upper center', shadow=True)

fig.savefig('../../../../LatticePaper/subplots.pdf')
fig.show()
